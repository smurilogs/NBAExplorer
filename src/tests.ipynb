# %%
from nbaexplorer import NBAExplorer

explorer = NBAExplorer(seasons=[2015])
games_df = explorer.get_games_df()
games_df
# Out:
#       season      date      gameId          gameUrl  periods hTeam vTeam  \
# 0       2015  20151002  0011500001  20151002/DENLAC        4   LAC   DEN
# 1       2015  20151003  0011500002  20151003/CHAORL        4   ORL   CHA
# 2       2015  20151003  0011500003  20151003/NOPIND        4   IND   NOP
# 3       2015  20151004  0011500006  20151004/CHAMIA        4   MIA   CHA
# 4       2015  20151004  0011500005  20151004/LACTOR        4   TOR   LAC
# ...      ...       ...         ...              ...      ...   ...   ...
# 6868    2019  20200919  0041900303  20200919/BOSMIA        4   MIA   BOS
# 6869    2019  20200920  0041900312  20200920/DENLAL        4   LAL   DEN
# 6870    2019  20200922  0041900313  20200922/LALDEN        4   DEN   LAL
# 6871    2019  20200923  0041900304  20200923/BOSMIA        4   MIA   BOS
# 6872    2019  20200924  0041900314  20200924/LALDEN        4   DEN   LAL
#
#       hScore  vScore winner  deltaScore
# 0        103      96      H           7
# ...

# %%
plays_df = explorer.get_plays_df(game_id='0011500002')
plays_df
# Out:
#          date      gameId  gameSecond  period  periodSecond  hScore  vScore  \
# 0    20151003  0011500002           0       1             0       0       0
# 1    20151003  0011500002           0       1             0       0       0
# 2    20151003  0011500002          16       1            16       0       0
# 3    20151003  0011500002          17       1            17       0       0
# 4    20151003  0011500002          24       1            24       0       0
# ..        ...         ...         ...     ...           ...     ...     ...
# 453  20151003  0011500002        2870       4           710     100     106
# 454  20151003  0011500002        2870       4           710     100     106
# 455  20151003  0011500002        2879       4           719     100     106
# 456  20151003  0011500002        2879       4           719     100     106
# 457  20151003  0011500002        2880       4           720     100     106
#
# ...

# %%
teams_df = explorer.get_teams_df()
teams_df
# Out:
#         teamId team    confName    divName
# 0   1610612737  ATL        East  Southeast
# 1        12328  BAU  Internatio
# 2   1610612738  BOS        East   Atlantic
# 3   1610612751  BKN        East   Atlantic
# 4   1610616839  CAN
# 5   1610612766  CHA        East  Southeast
# 6   1610612741  CHI        East    Central
# 7   1610612739  CLE        East    Central
# 8   1610612742  DAL        West  Southwest
# 9   1610612743  DEN        West  Northwest
# 10  1610612765  DET        East    Central
# 11  1610616833  EST        East
# 12  1610612744  GSW        West    Pacific
# 13          93  MAC  Internatio
# 14  1610612745  HOU        West  Southwest
# 15  1610612754  IND        East    Central
# 16       12321  FEN  Internatio
# 17  1610612746  LAC        West    Pacific
# 18  1610612747  LAL        West    Pacific
# 19  1610612763  MEM        West  Southwest
# 20  1610612748  MIA        East  Southeast
# 21          94  MLN  Internatio
# ...
